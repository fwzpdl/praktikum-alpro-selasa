# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA & PEMOGRAMAN**
#
# **“TIPE DATA DAN VARIABEL”**
#
# **Disusun Oleh :**
#
# **Muhammad Fawwaz**
#
# **2611532015**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Rifky Yuliandra**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# #
# #
# #
# #
#
#
#
#
#
#
#
# <h1 align="center">KATA PENGANTAR</h1>
#
# Puji syukur penulis panjatkan ke hadirat Tuhan Yang Maha Esa atas segala rahmat dan berkat-Nya, sehingga penulis dapat menyelesaikan laporan praktikum yang telah dilaksanakan sebagai pertemuan pertama pada mata kuliah Algoritma dan Pemrograman dengan judul “Tipe Data dan Variabel”. Praktikum ini berfokus pada pembahasan mengenai konsep dasar tipe data serta variabel yang menjadi fondasi penting dalam memahami algoritma dan pemrograman.
#
# Melalui praktikum ini, diharapkan penulis mampu memahami dan mengimplementasikan secara langsung konsep tipe data dan variabel dalam sebuah real project. Pemahaman ini akan menjadi bekal awal untuk menguasai materi algoritma yang lebih kompleks di pertemuan-pertemuan berikutnya.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan serta pengembangan di masa mendatang.
#
# <p align="right">Padang, 2026</p>

# %% [markdown]
# <h1 align= "center">BAB I</h1>
# <h1 align= "center">PENDAHULUAN</h1>
#
# ## 1.1 Latar Belakang
# Konsep tipe data dan variabel merupakan dasar yang sangat penting dalam pemrograman karena setiap program bergantung pada cara data disimpan, diolah, dan digunakan untuk membangun logika yang terstruktur. Variabel berfungsi sebagai wadah untuk menyimpan nilai yang dapat berubah sesuai kebutuhan, sedangkan tipe data menentukan bentuk serta sifat dari nilai tersebut agar program dapat berjalan dengan benar. Pemahaman mengenai topik ini membantu pembelajar mengenali bagaimana komputer mengelola informasi, mulai dari perhitungan sederhana hingga pengambilan keputusan dalam algoritma. Praktikum dengan judul “Tipe Data dan Variabel” menjadi langkah awal untuk menghubungkan teori dengan praktik nyata, sehingga keterampilan dasar yang diperoleh dapat menjadi bekal dalam mempelajari konsep pemrograman yang lebih kompleks di tahap berikutnya.
#
# ## 1.2 Tujuan
# 1. Memahami konsep dasar tipe data dan variabel dalam pemrograman.
# 2. Mengetahui fungsi serta peran variabel sebagai wadah penyimpanan data.
# 3. Menghubungkan teori dengan praktik nyata melalui implementasi konsep dasar pada program sederhana.
# ## 1.3 Manfaat
# 1. Melatih kemampuan berpikir logis dan sistematis dalam menyusun program.
# 2. Menjadi bekal untuk memahami konsep pemrograman yang lebih kompleks di pertemuan berikutnya.
# 3. Membantu menghubungkan teori dengan praktik nyata melalui implementasi kode sederhana.

# %% [markdown]
# <h1 align="center">BAB II</h1>
# <h1 align="center">PEMBAHASAN</h1>
#
#
# ## 2.1 Dasar Teori
#
# 1. Numerik<br>
# Tipe data numerik digunakan untuk merepresentasikan bilangan bulat maupun pecahan dalam pemrograman. Komputasi numerik menjadi fondasi dalam berbagai aplikasi IT seperti machine learning, grafika komputer, dan simulasi sistem kompleks. Representasi bilangan dan algoritma numerik membantu komputer melakukan operasi aritmatika dengan presisi tertentu.
#
# 2. String. <br>
# String adalah kumpulan karakter yang digunakan untuk menyimpan dan memanipulasi teks. Dalam bahasa Python, string direpresentasikan dengan tanda kutip tunggal ('...') atau ganda ("...") dan dapat berisi huruf, angka, simbol, maupun karakter khusus.
# 3. Input. <br>
# Input adalah mekanisme untuk menerima data dari pengguna agar program dapat berinteraksi secara dinamis. Fungsi input memungkinkan nilai variabel ditentukan saat program berjalan, bukan hanya saat kompilasi. Hal ini penting untuk membangun aplikasi interaktif.
# 4. Boolean. <br>
# Boolean adalah tipe data logika yang hanya memiliki dua nilai: true dan false. Konsep ini diperkenalkan oleh George Boole dan menjadi dasar dalam pengambilan keputusan (percabangan, loop, kontrol alur). Boolean juga digunakan dalam desain rangkaian digital dan algoritma logika.
# 5. Konstanta. <br>
# Konstanta adalah nilai tetap yang tidak dapat diubah selama eksekusi program. Penggunaan konstanta menjaga konsistensi dan memudahkan pemeliharaan kode, misalnya mendefinisikan nilai π atau batas maksimum. Konstanta dapat ditulis dengan const atau #define tergantung bahasa pemrograman.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "A_2611532015"
# **a. Program String**

# %%
nama_2015 = "Muhammad Fawwaz"
jenis_kelamin_2015 = 'Laki-laki'
alamat_2015 = """
Limau Manis
Kec.Pauh
Kota Padang
"""
agama_2015 = 'islam'
print("Nama saya adalah:", nama_2015)
print("Jenis kelamin saya adalah:", jenis_kelamin_2015)
print("Alamat saya adalah:", alamat_2015)
print("Agama saya adalah:", agama_2015)
# Out:
# Nama saya adalah: Muhammad Fawwaz
# Jenis kelamin saya adalah: Laki-laki
# Alamat saya adalah:
# Limau Manis
# Kec.Pauh
# Kota Padang
#
# Agama saya adalah: islam

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1–4 → Pendefinisian variabel untuk menyimpan data berupa string (nama, jenis kelamin, alamat, agama).
# 2. Baris 5–8 → Fungsi print() digunakan untuk menampilkan isi variabel ke layar bersama teks keterangan.
# 3. Baris 3 → Variabel alamat_2015 menggunakan string multiline ("""...""") sehingga teks alamat bisa ditulis dalam beberapa baris.

# %% [markdown]
# **b. Program Numerik**

# %%
a_2015 = 100
print("The type of variabel having value", a_2015,"is", type(a_2015))
b_2015 = 10.2345
print("The type of variabel having value", b_2015,"is", type(b_2015))
c_2015 = 100+3j
print("The type of variabel having value", c_2015,"is", type(c_2015))
# Out:
# The type of variabel having value 100 is <class 'int'>
# The type of variabel having value 10.2345 is <class 'float'>
# The type of variabel having value (100+3j) is <class 'complex'>

# %% [markdown]
# **Penjelasan:**
#
# 1. Baris 1 → Variabel a_2015 menyimpan nilai integer (bilangan bulat).
# 2. Baris 2 → print() menampilkan nilai variabel a_2015 sekaligus menunjukkan tipe datanya dengan fungsi type().
# 3. Baris 3 → Variabel b_2015 menyimpan nilai float (bilangan desimal).
# 4. Baris 4 → print() menampilkan nilai variabel b_2015 sekaligus menunjukkan tipe datanya dengan fungsi type().
# 5. Baris 5 → Variabel c_2015 menyimpan nilai complex (bilangan kompleks dengan bagian imajiner).
# 6. Baris 6 → print() menampilkan nilai variabel c_2015 sekaligus menunjukkan tipe datanya dengan fungsi type().

# %% [markdown]
# **c. Program Boolean.**

# %%
is_lulus_2015 = True
is_cumloude_2015 = True
nilai_2015 = 90
batas_lulus_2015 = 75

status_kelulusan_2015 = nilai_2015 >= batas_lulus_2015 #Hasilnya akan lulus 
print("=== Check Kelulusan ===")
print("Nilai", nilai_2015)
print("Apakah Lulus?:", status_kelulusan_2015)
if is_lulus_2015 and is_cumloude_2015:
    print("Selamat, Anda lulus dengan predikat CumLaude!")
# Out:
# === Check Kelulusan ===
# Nilai 90
# Apakah Lulus?: True
# Selamat, Anda lulus dengan predikat CumLaude!

# %% [markdown]
# **Penjelasan:**
#
# 1. Baris 1–2 → Variabel is_lulus_2015 dan is_cumloude_2015 menyimpan nilai boolean (True) untuk menandai status kelulusan dan predikat CumLaude.
# 2. Baris 3–4 → Variabel nilai_2015 dan batas_lulus_2015 menyimpan nilai numerik (integer) untuk skor ujian dan batas minimal kelulusan.
# 3. Baris 6 → Variabel status_kelulusan_2015 menyimpan hasil perbandingan logika nilai_2015 >= batas_lulus_2015, menghasilkan nilai boolean sesuai kondisi.
# 4. Baris 7–9 → Fungsi print() digunakan untuk menampilkan teks keterangan dan nilai variabel ke layar.
# 5. Baris 10–11 → Struktur kontrol if mengecek kondisi gabungan is_lulus_2015 and is_cumloude_2015. Jika keduanya bernilai True, maka program menampilkan pesan “Selamat, Anda lulus dengan predikat CumLaude!”.

# %% [markdown]
# **d. Program Input**

# %%
panjang_2015 = input("Masukkan nilai panjang: ")
lebar_2015 = input('Masukkan nilai lebar: ')
luas_2015 = int(panjang_2015) * int(lebar_2015)
print("Luas:", luas_2015)

# %% [markdown]
# **Penjelasan:**
#
# 1. Baris 1 → panjang_2015 = input("Masukkan nilai panjang: ") berfungsi untuk menerima input dari pengguna berupa teks (string) dan menyimpannya ke variabel panjang_2015.
# 2. Baris 2 → lebar_2015 = input('Masukkan nilai lebar: ') berfungsi untuk menerima input dari pengguna berupa teks (string) dan menyimpannya ke variabel lebar_2015.
# 3. Baris 3 → luas_2015 = int(panjang_2015) * int(lebar_2015) mengubah input string menjadi integer dengan fungsi int(), lalu menghitung perkalian panjang × lebar untuk mendapatkan nilai luas.
# 4. Baris 3 → luas_2015 = int(panjang_2015) * int(lebar_2015) mengubah input string menjadi integer dengan fungsi int(), lalu menghitung perkalian panjang × lebar untuk mendapatkan nilai luas.

# %% [markdown]
# **e. Program Konstanta**

# %%
from typing import Final
PI: Final = 3.14
print("pi: %f" % (PI))
jari_2015 = float(input('Masukkan nilai jari-jari: '))
luas_2015 = PI * jari_2015 * jari_2015
print("Luas lingkaran dengan jari-jari %.2f adalah %.2f" % (jari_2015, luas_2015))

# %% [markdown]
# **Penjelasan:**
#
# 1. Baris 1 → from typing import Final digunakan untuk mengimpor anotasi Final dari modul typing, yang menandai bahwa sebuah variabel bersifat konstan (tidak boleh diubah).
# 2. Baris 2 → PI: Final = 3.14 mendefinisikan konstanta PI dengan nilai 3.14.
# 3. Baris 3 → print("pi: %f" % (PI)) menampilkan nilai konstanta PI dalam format float.
# 4. Baris 4 → jari_2015 = float(input('Masukkan nilai jari-jari: ')) menerima input dari pengguna, mengubahnya menjadi tipe data float, lalu menyimpannya ke variabel jari_2015.
# 5. Baris 5 → luas_2015 = PI * jari_2015 * jari_2015 menghitung luas lingkaran dengan rumus π × r × r menggunakan nilai konstanta PI dan variabel jari_2015.
# 6. Baris 6 → print("Luas lingkaran dengan jari-jari %.2f adalah %.2f" % (jari_2015, luas_2015)) menampilkan hasil perhitungan luas lingkaran dengan format dua angka di belakang koma.

# %% [markdown]
# <h1 align="center">BAB III</h1>
# <h1 align="center">KESIMPULAN</h1>
#
#
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python menyediakan dasar-dasar penting dalam pemrograman, yaitu penggunaan variabel untuk menyimpan data, tipe data yang beragam seperti string, numerik (integer, float, complex), boolean, serta konstanta untuk nilai tetap. Dalam konteks pemrograman, konsep ini memanfaatkan fungsi input() untuk menerima data dari pengguna, print() untuk menampilkan hasil, operator logika dan perbandingan untuk menentukan kondisi, serta struktur kontrol seperti if untuk pengambilan keputusan sehingga program dapat berjalan secara interaktif, terstruktur, dan mampu menghasilkan keluaran sesuai dengan kebutuhan.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, "The Python Tutorial — Python 3.14.7 Documentation," Python.org, [2026]. [Online]. Tersedia: https://docs.python.org/3/tutorial/index.html [Diakses 9 September 2026].
#
# [2] Python Software Foundation, "Data Model — Boolean Operations," Python.org, [2026]. [Online]. Tersedia: https://docs.python.org/3/reference/datamodel.html [Diakses 9 September 2026].
#
# [3] John Zelle, "Python Programming: An Introduction to Computer Science, 3rd Edition," Franklin, Beedle & Associates, [2016], Hal. 20–75.
#
# [4] Charles Severance, "Python for Everybody: Exploring Data Using Python 3," University of Michigan, [2016]. [Online]. Tersedia: https://www.py4e.com/book [Diakses 9 September 2026].
