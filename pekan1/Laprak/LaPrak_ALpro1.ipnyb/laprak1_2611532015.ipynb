# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA DAN PEMOGRAMAN**
#
# **“PENGENALAN PYTHON, VISUAL STUDIO CODE DAN KONEKSI KE GITHUB”**
#
# **Disusun Oleh :**
#
# **Muhammad Fawwaz**
#
# **2611532015**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Rifki Yuliandra**
#
# <br>
#
#  <img src="../images/unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# <h1 align = "center"> KATA PENGANTAR </h1>
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum pengenalan dasar python, vs code dan koneksi ke github yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Algoritma dan Pemograman. Praktikum ini berfokus pada pembahasan
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep dasar bahasa pemograman Python pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# <p align = "right">Padang, 2026</p>

# %% [markdown]
# ---
# <h1 align = "center">  BAB I </h1>
# <h1 align = "center">  PENDAHULUAN </h1>
#
#
# ## 1.1 Latar Belakang
#   Python merupakan bahasa pemrograman yang populer karena sintaksnya sederhana dan fleksibel untuk berbagai kebutuhan, mulai dari analisis data hingga pengembangan aplikasi. Untuk mendukung proses belajar, Visual Studio Code (VS Code) digunakan sebagai editor yang ringan dan kaya fitur. Sementara itu, GitHub berfungsi sebagai platform penyimpanan dan kolaborasi kode dengan sistem version control.
#
#   Praktikum ini bertujuan mengenalkan dasar Python, penggunaan VS Code, serta cara menghubungkan proyek ke GitHub agar saya sebagai mahasiswa terbiasa dengan ekosistem pengembangan perangkat lunak modern.
#
# ## 1.2 Tujuan
# 1. Memahami dasar-dasar bahasa pemrograman Python sebagai langkah awal belajar coding.
# 2. Mengenal dan menggunakan Visual Studio Code (VS Code) sebagai editor utama dalam menulis dan menjalankan program.
# 3. Mempelajari cara menghubungkan proyek ke GitHub untuk manajemen versi dan kolaborasi.
#
# ## 1.3 Manfaat
# 1. Memberikan pemahaman dasar tentang bahasa pemrograman Python yang mudah dipelajari dan banyak digunakan.
# 2. Melatih keterampilan menggunakan VS Code sebagai editor yang mendukung produktivitas dalam menulis dan menjalankan program.

# %% [markdown]
# ---
# <h1 align = "center">   BAB II</h1>
# <h1 align = "center">  PEMBAHASAN </h1>
#
#
# ## 2.1 Dasar Teori
#
# 1. Python.  Python adalah bahasa pemrograman tingkat tinggi yang bersifat interpreted dan general-purpose. Bahasa ini dikenal dengan sintaks yang sederhana, mudah dipahami, serta memiliki pustaka standar yang luas. Python banyak digunakan dalam bidang analisis data, pengembangan web, kecerdasan buatan, dan otomasi.
#
# 2. Visual Studio Code (VS Code).VS Code merupakan source-code editor yang dikembangkan oleh Microsoft. Editor ini mendukung berbagai bahasa pemrograman, termasuk Python, serta dilengkapi fitur seperti extensions, debugging, dan integrasi dengan Git. VS Code menjadi salah satu editor populer karena ringan, fleksibel, dan ramah pengguna.
#
# 3. Git dan GitHub.Git adalah sistem kontrol versi (version control system) yang digunakan untuk melacak perubahan pada kode. GitHub adalah platform berbasis web yang menyediakan layanan penyimpanan repositori Git serta mendukung kolaborasi antar pengguna. Dengan GitHub, pengembang dapat mengelola proyek secara terstruktur, berbagi kode, dan bekerja dalam tim.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "A_2611532015"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
##program pertama
"""
komentar 
dua baris atau lebih
pertemuan 1 praktikum alpro
"""
print("hello world")
print()
print("program ini menghasilkan")
print("Empat baris output")
print("/ \\ // \\\\ /// \\\\\\")
print("program ini " + "dibuat oleh \n " + "Muhammad Fawwaz")
# Out:
# hello world
#
# program ini menghasilkan
# Empat baris output
# / \ // \\ /// \\\
# program inidibuat oleh
#  Muhammad Fawwaz

# %% [markdown]
# **Penjelasan :**
# 1. Baris pertama kode ini # berfungsi untuk memberikan komentar
# 2. Bagian kedua dengan kode """ berfungsi untuk string
# 3. Bagian ketiga print() berfungsi untuk menampilkan output kelayar

# %% [markdown]
# ---
# <h1 align = "center">BAB III</h1>
#
# <h2 align = "center">KESIMPULAN</h2>
#
# Praktikum “Pengenalan Python, VS Code, dan Koneksi ke GitHub” memberikan pemahaman dasar mengenai ekosistem pengembangan perangkat lunak modern. Python sebagai bahasa pemrograman yang sederhana dan fleksibel menjadi fondasi utama dalam belajar coding. VS Code digunakan sebagai editor yang mendukung produktivitas dengan fitur debugging dan integrasi Git, sehingga proses penulisan serta pengelolaan kode menjadi lebih efisien. Sementara itu, GitHub berperan penting dalam manajemen versi dan kolaborasi, memungkinkan mahasiswa untuk terbiasa bekerja dalam tim dan mengatur proyek secara terstruktur. Dengan menguasai ketiga komponen ini, peserta praktikum memperoleh bekal awal yang kuat untuk melanjutkan pembelajaran pemrograman dan pengembangan aplikasi secara lebih profesional.

# %% [markdown]
# ---
# <h1 align = "center">DAFTAR PUSTAKA</h1>
#
# [1] Python Software Foundation. Python Documentation. Diakses dari: https://docs.python.org
#
# [2] Microsoft. Visual Studio Code Documentation. Diakses dari: https://code.visualstudio.com/docs
#
# [3] GitHub Docs. Getting Started with GitHub. Diakses dari: https://docs.github.com
